# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision.datasets import ImageFolder
from torchvision.models import vgg16
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import numpy as np
import pandas as pd
# Out:
# c:\Users\Wall-E\.conda\envs\vakkas\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] Belirtilen yordam bulunamadı'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
# Veri kümesini yükleme
DATASET_PATH = "kvasir-dataset-v2"  # Buraya veri kümenizin yolunu ekleyin
RESULTS_DIR = "vgg16"  # Kayıt klasörü
os.makedirs(RESULTS_DIR, exist_ok=True)

# %%
# Görüntü boyutu ve batch size
target_size = (224, 224)  # resnet50 için uygun boyut
batch_size = 32

# Veri ön işleme
transform = transforms.Compose([
    transforms.Resize(target_size),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# %%
# Tüm veri kümesini yükleme
full_dataset = ImageFolder(root=os.path.join(DATASET_PATH), transform=transform)

# Veri kümesini bölme (70% train, 20% validation, 10% test)
train_size = int(0.8 * len(full_dataset))
val_size = int(0.1 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# VGG16 Modeli
model = vgg16(pretrained=True)
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 8)  # 8 sınıf için güncellendi
# Out:
# c:\Users\Wall-E\.conda\envs\vakkas\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Wall-E\.conda\envs\vakkas\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to C:\Users\Wall-E/.cache\torch\hub\checkpoints\vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:13<00:00, 40.3MB/s]

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # GPU 1 kullanımı için güncellendi
model.to(device)

print(f"using device: {device}")
devNumber=torch.cuda.current_device()
print(f"curennt device number is:{devNumber}")
devName=torch.cuda.get_device_name()
print(f"gpu name is {devName}")
# Out:
# using device: cuda:0
# curennt device number is:0
# gpu name is NVIDIA GeForce RTX 2080 Ti

# %%
# Kayıp fonksiyonu ve optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)

# Sonuçları kaydetmek için boş bir DataFrame oluşturma
results = []

# %%
# Modeli eğitme
epochs = 50
train_losses, val_accuracies = [], []
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    train_losses.append(running_loss / len(train_loader))

    # Doğrulama testi
    model.eval()
    correct, total = 0, 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    f1 = f1_score(all_labels, all_preds, average='macro')
    val_accuracies.append(accuracy)

     # Sonuçları kaydet
    results.append([epoch + 1, train_losses[-1], accuracy, precision, recall, f1])
    print(
        f"Epoch {epoch + 1}/{epochs}, Loss: {train_losses[-1]:.4f}, Val Acc: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")
# Out:
# Epoch 1/50, Loss: 0.5633, Val Acc: 0.8875, Precision: 0.9003, Recall: 0.8873, F1: 0.8848
# Epoch 2/50, Loss: 0.2645, Val Acc: 0.8688, Precision: 0.8820, Recall: 0.8683, F1: 0.8707
# Epoch 3/50, Loss: 0.1999, Val Acc: 0.9087, Precision: 0.9208, Recall: 0.9091, F1: 0.9060
# Epoch 4/50, Loss: 0.1361, Val Acc: 0.9062, Precision: 0.9110, Recall: 0.9080, F1: 0.9065
# Epoch 5/50, Loss: 0.1334, Val Acc: 0.9050, Precision: 0.9104, Recall: 0.9051, F1: 0.9047
# Epoch 6/50, Loss: 0.0966, Val Acc: 0.9287, Precision: 0.9315, Recall: 0.9288, F1: 0.9282
# Epoch 7/50, Loss: 0.0639, Val Acc: 0.9425, Precision: 0.9443, Recall: 0.9423, F1: 0.9426
# Epoch 8/50, Loss: 0.0458, Val Acc: 0.9187, Precision: 0.9225, Recall: 0.9205, F1: 0.9188
# Epoch 9/50, Loss: 0.0665, Val Acc: 0.9337, Precision: 0.9358, Recall: 0.9331, F1: 0.9332
# Epoch 10/50, Loss: 0.0391, Val Acc: 0.9325, Precision: 0.9335, Recall: 0.9338, F1: 0.9330
# Epoch 11/50, Loss: 0.1519, Val Acc: 0.9163, Precision: 0.9227, Recall: 0.9184, F1: 0.9173
# Epoch 12/50, Loss: 0.0438, Val Acc: 0.9225, Precision: 0.9329, Recall: 0.9231, F1: 0.9206
# Epoch 13/50, Loss: 0.0515, Val Acc: 0.8975, Precision: 0.9021, Recall: 0.8964, F1: 0.8964
# Epoch 14/50, Loss: 0.0439, Val Acc: 0.9425, Precision: 0.9432, Recall: 0.9424, F1: 0.9424
# Epoch 15/50, Loss: 0.0153, Val Acc: 0.9300, Precision: 0.9319, Recall: 0.9310, F1: 0.9308
# Epoch 16/50, Loss: 0.0426, Val Acc: 0.9350, Precision: 0.9373, Recall: 0.9357, F1: 0.9348
# Epoch 17/50, Loss: 0.0296, Val Acc: 0.9337, Precision: 0.9366, Recall: 0.9347, F1: 0.9338
# Epoch 18/50, Loss: 0.0472, Val Acc: 0.9213, Precision: 0.9265, Recall: 0.9229, F1: 0.9213
# Epoch 19/50, Loss: 0.0342, Val Acc: 0.9150, Precision: 0.9196, Recall: 0.9135, F1: 0.9131
# Epoch 20/50, Loss: 0.0259, Val Acc: 0.9100, Precision: 0.9209, Recall: 0.9107, F1: 0.9085
# Epoch 21/50, Loss: 0.0124, Val Acc: 0.9425, Precision: 0.9442, Recall: 0.9430, F1: 0.9428
# Epoch 22/50, Loss: 0.0245, Val Acc: 0.9250, Precision: 0.9264, Recall: 0.9261, F1: 0.9249
# Epoch 23/50, Loss: 0.0369, Val Acc: 0.9237, Precision: 0.9265, Recall: 0.9245, F1: 0.9233
# Epoch 24/50, Loss: 0.0767, Val Acc: 0.9100, Precision: 0.9131, Recall: 0.9103, F1: 0.9098
# Epoch 25/50, Loss: 0.0536, Val Acc: 0.9200, Precision: 0.9222, Recall: 0.9208, F1: 0.9196
# Epoch 26/50, Loss: 0.0224, Val Acc: 0.9175, Precision: 0.9203, Recall: 0.9169, F1: 0.9175
# Epoch 27/50, Loss: 0.0250, Val Acc: 0.9113, Precision: 0.9150, Recall: 0.9122, F1: 0.9121
# Epoch 28/50, Loss: 0.0169, Val Acc: 0.9350, Precision: 0.9360, Recall: 0.9351, F1: 0.9348
# Epoch 29/50, Loss: 0.0163, Val Acc: 0.9287, Precision: 0.9326, Recall: 0.9291, F1: 0.9287
# Epoch 30/50, Loss: 0.0245, Val Acc: 0.9163, Precision: 0.9220, Recall: 0.9166, F1: 0.9169
# Epoch 31/50, Loss: 0.0122, Val Acc: 0.9213, Precision: 0.9226, Recall: 0.9222, F1: 0.9217
# Epoch 32/50, Loss: 0.0490, Val Acc: 0.8988, Precision: 0.9036, Recall: 0.8985, F1: 0.8985
# Epoch 33/50, Loss: 0.0462, Val Acc: 0.8812, Precision: 0.8903, Recall: 0.8823, F1: 0.8788
# Epoch 34/50, Loss: 0.0205, Val Acc: 0.9275, Precision: 0.9298, Recall: 0.9274, F1: 0.9271
# Epoch 35/50, Loss: 0.0066, Val Acc: 0.9200, Precision: 0.9239, Recall: 0.9195, F1: 0.9199
# Epoch 36/50, Loss: 0.0178, Val Acc: 0.9263, Precision: 0.9313, Recall: 0.9279, F1: 0.9268
# Epoch 37/50, Loss: 0.0275, Val Acc: 0.9012, Precision: 0.9095, Recall: 0.9015, F1: 0.8994
# Epoch 38/50, Loss: 0.0458, Val Acc: 0.9225, Precision: 0.9259, Recall: 0.9232, F1: 0.9226
# Epoch 39/50, Loss: 0.0242, Val Acc: 0.9313, Precision: 0.9347, Recall: 0.9317, F1: 0.9320
# Epoch 40/50, Loss: 0.0179, Val Acc: 0.9163, Precision: 0.9230, Recall: 0.9178, F1: 0.9171
# Epoch 41/50, Loss: 0.0228, Val Acc: 0.9100, Precision: 0.9186, Recall: 0.9096, F1: 0.9102
# Epoch 42/50, Loss: 0.0208, Val Acc: 0.9313, Precision: 0.9328, Recall: 0.9309, F1: 0.9312
# Epoch 43/50, Loss: 0.0370, Val Acc: 0.9237, Precision: 0.9270, Recall: 0.9257, F1: 0.9248
# Epoch 44/50, Loss: 0.0335, Val Acc: 0.9150, Precision: 0.9192, Recall: 0.9153, F1: 0.9148
# Epoch 45/50, Loss: 0.0285, Val Acc: 0.9237, Precision: 0.9245, Recall: 0.9241, F1: 0.9237
# Epoch 46/50, Loss: 0.0291, Val Acc: 0.9337, Precision: 0.9359, Recall: 0.9340, F1: 0.9342
# Epoch 47/50, Loss: 0.0104, Val Acc: 0.9425, Precision: 0.9453, Recall: 0.9433, F1: 0.9425
# Epoch 48/50, Loss: 0.0031, Val Acc: 0.9387, Precision: 0.9411, Recall: 0.9396, F1: 0.9391
# Epoch 49/50, Loss: 0.0059, Val Acc: 0.9187, Precision: 0.9206, Recall: 0.9195, F1: 0.9193
# Epoch 50/50, Loss: 0.0307, Val Acc: 0.9087, Precision: 0.9094, Recall: 0.9106, F1: 0.9089

# %%
# Sonuçları Excel'e kaydetme
df_results = pd.DataFrame(results,
                          columns=["Epoch", "Train Loss", "Validation Accuracy", "Precision", "Recall", "F1 Score"])
df_results.to_excel(os.path.join(RESULTS_DIR,"training_results.xlsx"), index=False)

# %%
# Eğitim ve doğrulama kayıplarını görselleştirme
plt.figure()
plt.plot(range(1, epochs + 1), train_losses, label='Train Loss')
plt.plot(range(1, epochs + 1), val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.title('Training Loss & Validation Accuracy')
plt.savefig(os.path.join(RESULTS_DIR,"training_plot.png"))
plt.show()

# %%
# Test sonuçları
test_results = []
test_correct, test_total = 0, 0
all_preds, all_labels = [], []
all_probs = []
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        _, predicted = torch.max(outputs, 1)
        all_probs.extend(probs)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_acc = accuracy_score(all_labels, all_preds)
conf_matrix = confusion_matrix(all_labels, all_preds)

# %%
# Confusion matrix çizimi
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=full_dataset.classes,
            yticklabels=full_dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.savefig(os.path.join(RESULTS_DIR,"confusion_matrix.png"))
plt.show()

# %%
# ROC-AUC Eğrisi
all_labels_bin = label_binarize(all_labels, classes=range(8))
all_probs = np.array(all_probs)
fpr, tpr, _ = roc_curve(all_labels_bin.ravel(), all_probs.ravel())
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.savefig(os.path.join(RESULTS_DIR,"roc_curve.png"))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # ROC-AUC Eğrisi
# ----> 2 all_labels_bin = label_binarize(all_labels, classes=range(8))
#       3 all_probs = np.array(all_probs)
#       4 fpr, tpr, _ = roc_curve(all_labels_bin.ravel(), all_probs.ravel())
#
# NameError: name 'label_binarize' is not defined

# %%
test_results.append([test_acc, precision, recall, f1])
df_test_results = pd.DataFrame(test_results, columns=["Test Accuracy", "Precision", "Recall", "F1 Score"])
df_test_results.to_excel(os.path.join(RESULTS_DIR,"testing_results.xlsx"), index=False)

print(f'Test Accuracy: {test_acc * 100:.2f}%')
print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Test Accuracy: 92.25%
# Confusion Matrix:
# [[110   6   0   0   0   0   1   1]
#  [  6  93   0   1   0   0   0   0]
#  [  0   0  66   0   0  19   0   0]
#  [  0   0   0 104   0   0   0   1]
#  [  0   0   0   0  97   1   1   0]
#  [  0   0   9   0   0  90   0   0]
#  [  1   0   0   5   1   0  92   4]
#  [  0   0   0   4   1   0   0  86]]
